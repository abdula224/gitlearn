# %%
import pandas as pd
car=pd.read_csv('car_upto.csv')
car.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000  45,000 kms
# 1           1     Mahindra Jeep CL550  Mahindra  2006  425000      40 kms
# 2           2       Hyundai Grand i10   Hyundai  2014  325000  28,000 kms
# 3           3  Ford EcoSport Titanium      Ford  2014  575000  36,000 kms
# 4           4               Ford Figo      Ford  2012  175000  41,000 kms
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel
